# %% [markdown]
# <a href="https://colab.research.google.com/github/Jhuleidy19/Tareas-Aplicadas/blob/main/Sesion5_Pensamiento_Computacional.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Unknown.png](data:image/png;base64,...)
#
# #**<big><big>Pensamiento Computacional</big></big><br><small>Depto. Computación y Sistemas Inteligentes de la FIDCA</small><br>Senderos del SI y el NO (Tipos de datos).</small>**
# -------

# %% [markdown]
# # <font color="orange">Introducción al Nivel 2: Explorador Lógico</font> <font color="lightblue">(5 min)</font>
#
# # ¡Felicidades, Neófitos del Código!
#
# Han superado el **Primer Nivel de Aprendizaje** y ahora portan con orgullo el título de **Neófitos del Código**. Han comprendido los pilares fundamentales: los **Tipos de Datos** que dan forma a la realidad, desde los **Números Sagrados** hasta los **Juramentos de Verdad**.
# Pero su viaje apenas comienza…
# Han llegado a **Los Senderos del SÍ o NO**, un lugar donde cada decisión cambia el destino. Aquí, deberán perfeccionar su habilidad en la lógica del código para ascender al rango de **Exploradores Lógicos.**
# El Guardián del Código los recibe con una advertencia:
# "Neófitos, el conocimiento que han adquirido les ha otorgado poder, pero ahora deben aprender a tomar decisiones. En el mundo del código, la lógica no se deja al azar. Cada elección se toma siguiendo caminos estructurados. Para avanzar, deberán dominar el arte de las **Decisiones Condicionales…**"
#
# # <font color="orange">El Sendero de las Decisiones: if, else y elif  </font> <font color="lightblue">(5 min)</font>
#
# **Recuerden el símbolo de decisión en los diagramas de flujo**: un **rombo** con una pregunta en su interior. Este símbolo representa el punto en el que el camino se bifurca, donde una elección debe ser tomada.
#
# **Estas decisiones se representan con los Condicionales del Código:**
#
# 1.	🔹 **El Camino del IF (Sí):** Se usa cuando **una única condición** debe cumplirse para avanzar.
# 2.	🔸 **El Sendero ELSE (No):** Se usa cuando la primera condición **no se cumple**, dando otra opción.
# 3.	🔷 **La Ruta de las Posibilidades (ELIF - Otra opción intermedia):** Se usa cuando hay **varias condiciones posibles** antes de llegar a un resultado final.
#
# # <font color="orange">El Desordenador y el Código Perdido </font> <font color="lightblue">(5 min)</font>
#
# Hace muchos ciclos, en el mundo de **Datarealm**, la realidad era regida por las **Cuatro Leyes del Conocimiento**, principios fundamentales que mantenían el equilibrio de todo lo existente. Estas leyes estaban custodiadas por el sabio **Guardián del Código**, quien aseguraba que cada dato estuviera en su lugar correcto.
# Sin embargo, en las sombras de la Gran Red, un ser conocido como **El Desordenador** emergió con una intención peligrosa: **corromper la lógica del mundo y sumir Datarealm en el caos**. Este villano desató un hechizo que mezcló los valores de la realidad, confundiendo números con palabras, haciendo que los juramentos de verdad se volvieran inestables y alterando el flujo del código sagrado.
# Los exploradores del Código Perdido han sido convocados para restaurar el orden. Pero antes de embarcarse en esta misión, deben aprender a **distinguir y utilizar correctamente las Cuatro Leyes del Conocimiento**. Solo con este saber podrán derrotar al Desordenador y devolver el equilibrio al reino.

# %% [markdown]
# # <font color="orange">Primera Ley: La Energía de los Números (int y float) </font> <font color="lightblue">(10 min)</font>
#
# Los números son el **pilar de la realidad** en Datarealm. Son usados por guerreros, comerciantes, arquitectos y hechiceros para medir, calcular y predecir. Sin ellos, el reino se sumiría en el descontrol.
#
# ## Ejemplo 1 - La Fuerza de los Guerreros
# Los caballeros del reino deben tener un nivel de fuerza adecuado para blandir sus armas. Un caballero con **fuerza menor a 50** no puede usar la **Espada de Luz**.

# %%
fuerza = 45      #Entero (int)
if fuerza >= 50:
  print("Puedes usar la Espada de Luz.")
else:
  print("Tu fuerza es insuficiente. Necesitas entrenar.")
# Out:
# Tu fuerza es insuficiente. Necesitas entrenar.

# %% [markdown]
# # Ejemplo 2 - La Economía del Reino
# Los comerciantes usan números decimales **(float)** para manejar precios y evitar fraudes en las transacciones.
# ![Imagen 1.png](data:image/png;base64,...)
#
# **Regla del Código del Guardián:**
# •	**int (Enteros):** Usado para contar pociones, espadas o niveles de fuerza.
# •	**float (Decimales):** Usado para medir distancias, calcular pesos o manejar precios.

# %% [markdown]
# # <font color="orange">Segunda Ley: Las Palabras Encantadas (str - Strings) </font> <font color="lightblue">(5 min)</font>
#
# Las palabras tienen un poder especial en Datarealm, pues contienen la esencia de los nombres, conjuros y mensajes ocultos. Cuando las palabras se confunden con números, los hechizos fallan y los pergaminos se vuelven ilegibles.
#
# # Ejemplo 3 - El Nombre del Elegido
#
# Los aventureros deben inscribirse en el Registro del Destino antes de recibir una misión.

# %%
nombre : input("Ingresa tu nombre, viajero: ")
print("Bienvenido al Registro del Destino", + nombre + ".")

# %% [markdown]
# # Ejemplo 4 - El Pergamino de los Conjuros
# Si un mago quiere lanzar un hechizo, debe pronunciar correctamente su **frase mágica**.
# ![Imagen 2.png](data:image/png;base64,...)

# %% [markdown]
# **Regla del Código del Guardián:**
#
# •	**str (Strings):** Usado para nombres, inscripciones en pergaminos y hechizos.
# **¡Advertencia!** Si mezclamos números y palabras sin convertirlos, el Código se romperá:
#
# ![Imagen 3.png](data:image/png;base64,...)

# %% [markdown]
# Para evitar esto, debemos convertir el número en texto:

# %%
nivel = 1
print("Tu nivel es :" + str(nivel)) # Correcto

# %% [markdown]
# # <font color="orange">Tercera Ley: Los Juramentos de Verdad (bool - Booleanos) </font> <font color="lightblue">(5 min)</font>
#
# En Datarealm, los juramentos de verdad determinan el destino de los viajeros. Son respuestas absolutas: **Sí o No, Verdadero o Falso**. La lógica del mundo depende de que estos valores sean usados correctamente.
#
# # Ejemplo 5 - El Puente de la Verdad
# Para cruzar el **Puente de la Verdad**, un explorador debe responder si ha completado su entrenamiento.

# %%
ha_completado_entrenamiento = True  # Booleano (bool)
if ha_completado_entrenamiento:
	print("El puente te permite pasar.")
else:
	print("El puente se cierra ante ti.")

# %% [markdown]
# # Ejemplo 6 - El Oráculo del Reino
# Los habitantes consultan al Oráculo con preguntas de **Sí o No** para tomar decisiones.
#
# ![Imagen 4.png](data:image/png;base64,...)
#
# **Regla del Código del Guardián:**
# •	**bool (Booleanos):** Se usa para tomar decisiones en base a condiciones verdaderas o falsas.

# %% [markdown]
# # <font color="orange">Cuarta Ley: La Conversión de la Realidad (Type Casting) (</font> <font color="lightblue">(5 min)</font>
#
# Cuando el Desordenador alteró la realidad, muchos valores fueron mezclados. Para restaurar el orden, los exploradores deben aprender a transformar datos cuando sea necesario.
# # Ejemplo 7 - La Llave Numérica
# Para abrir un portal, un mago debe ingresar un código. Sin embargo, la inscripción está escrita como texto y debe convertirse en número.

# %%
codigo  = "1234"  # String (str)
codigo_real = int(codigo)  # Convertiremos a número
print("El código secreto es:", codigo_real)
# Out:
# El código secreto es: 1234

# %% [markdown]
# # Ejemplo 8 - El Pergamino de Conversión
# Si un guardia quiere leer cuántas pociones lleva un viajero, debe convertir el número en texto para hablar con él.
#
# ![Imagen 5.png](data:image/png;base64,...)
#
#
# **Regla del Código del Guardián:**
#
# *	**Convertir números a texto:** str(50) → "50"
#
# *	**Convertir texto a números:** int("20") → 20
#
# *	**Convertir decimales a enteros:** int(4.7) → 4
#
# *	**Convertir verdad a número:** int(True) → 1

# %% [markdown]
# # <font color="orange">Misión: Restaurar el Código de Datarealm </font>
#
# **Instrucciones:**
# Cada ejercicio es un desafío dentro del mundo de **Datarealm**. Los exploradores deberán resolver cada prueba para avanzar en su misión de restaurar el equilibrio.
#
# <font color="orange">**Nivel 1: El Portal de los Números (int y float)**</font>
#
# **Objetivo:** Diferenciar entre enteros y flotantes, y usarlos correctamente en cálculos.
#
# <font color="lightblue">**Ejercicio**</font>
#
# **Desafío del Guerrero**<font color="lightblue">**(5 min)**</font>
#
# Un caballero necesita **50 puntos de fuerza** para empuñar la Espada de Luz. Escribe un programa que verifique si su fuerza es suficiente
#
# <font color="lightblue">**Respuesta**</font>

# %%
fuerza = int(input("ingrese su nivel de fuerza: "))
if fuerza >= 50:
    print("¡Tienes suficiente fuerza para empuñar la Espada de Luz!")
else:
    print("No tienes suficiente fuerza para empuñar la Espada de Luz.")
# Out:
# ingrese su nivel de fuerza: 45
# No tienes suficiente fuerza para empuñar la Espada de Luz.

# %% [markdown]
# **La Pócima del Hechicero** <font color="lightblue">**(7 min)**</font>
#
# Un alquimista está preparando una poción mágica y necesita **exactamente 3.5 litros** de esencia de dragón. Sin embargo, las botellas disponibles solo muestran números enteros. Escribe un programa que convierta un número entero en flotante y verifique si la cantidad es suficiente.

# %%
litros_disponibles = int(input("Introduce la cantidad de litros de esencia de dragón en botellas (número entero): "))

litros_disponibles = float(litros_disponibles)

if litros_disponibles float >= esencia_necesaria

    print("¡Tienes suficiente esencia de dragón !")
else:
    print("No tienes suficiente esencia de dragón.")
# Out:
#   File "<ipython-input-13-bd3c4d4c8256>", line 5
#     if litros_disponibles float >= esencia_necesaria :
#                           ^
# SyntaxError: invalid syntax

# %% [markdown]
# <font color="orange">**Nivel 2: Las Palabras Encantadas (str)**</font>
#
# **Objetivo:** Manipular cadenas de texto correctamente.
#
# <font color="lightblue">**Ejercicio**</font>
#
# **El Pergamino Perdido** <font color="lightblue">**(5 min)**</font>
#
# Un mago ha encontrado un pergamino, pero su inscripción está oculta. Escribe un programa que **pida el nombre del hechizo y lo muestre en pantalla**.
#
#
# <font color="lightblue">**Respuesta**</font>

# %%
hechizo= input("ingrese el nombre del hechizo : ")
print("el hechizo es:" + hechizo)
# Out:
# ingrese el nombre del hechizo : kjhbgfc
# el hechizo es:kjhbgfc

# %% [markdown]
# **El Mensajero del Reino** <font color="lightblue">**(6 min)**</font>
#
# Un explorador debe entregar un mensaje real. Escribe un programa que combine el **nombre del explorador y el mensaje** en una sola oración.
#
#
# <font color="lightblue">**Respuesta**</font>

# %% [markdown]
# <font color="orange">**Nivel 3: Los Juramentos de Verdad (bool)**</font>
#
# **Objetivo:** Aplicar valores booleanos para la toma de decisiones.
#
# <font color="lightblue">**Ejercicio**</font>
#
# **El Puente de la Verdad** <font color="lightblue">**(7 min)**</font>
#
# Solo los viajeros con una llave mágica **(True)** pueden cruzar el puente encantado. Escribe un programa que verifique si un viajero tiene la llave y muestre el mensaje adecuado.
#
#
# <font color="lightblue">**Respuesta**</font>

# %% [markdown]
# <font color="lightblue">**Ejercicio**</font>
#
# **La Espada Encantada** <font color="lightblue">**(8 min)**</font>
#
# Solo los caballeros **con más de 75 puntos de honor** pueden desenvainar la Espada del Destino. Escribe un programa que determine si un caballero puede obtenerla.
#
#
# <font color="lightblue">**Respuesta**</font>

# %% [markdown]
# <font color="orange">**Nivel 4: La Conversión de la Realidad (Type Casting)**</font>
#
# **Objetivo:** Convertir entre diferentes tipos de datos.
#
# <font color="lightblue">**Ejercicio**</font>
#
# **El Código del Portal** <font color="lightblue">**(6 min)**</font>
#
# Para abrir un portal mágico, un viajero debe ingresar un código. Sin embargo, el código es un número almacenado como texto. Escribe un programa que **convierta el código en número** y verifique si es correcto.
#
#
# <font color="lightblue">**Respuesta**</font>

# %% [markdown]
# <font color="lightblue">**Ejercicio**</font>
#
# **El Inventario del Comerciante** <font color="lightblue">**(7 min)**</font>
#
# Un comerciante tiene una cantidad de **pociones almacenadas como un número entero**. Para mostrarlo en su lista de ventas, debe convertirlo en una cadena de texto.
#
#
# <font color="lightblue">**Respuesta**</font>

# %% [markdown]
# <font color="orange">**Nivel 5: El Desafío del Guardián**</font>
#
# **Objetivo:** Combinar todos los conceptos en un reto final.
#
# <font color="lightblue">**Ejercicio**</font>
#
# **El Reto del Guardián del Código** <font color="lightblue">**(12 min)**</font>
#
# El Guardián ha preparado una prueba definitiva. Para aprobar, un explorador debe **tener más de 18 años, ingresar su nombre correctamente y tener la llave del código.**
#
#
# <font color="lightblue">**Respuesta**</font>

# %% [markdown]
# # <font color="orange">Segunda Ley: Las Palabras Encantadas (str - Strings) </font> <font color="lightblue">(5 min)</font>
#
# **En las profundidades del vacío digital, entre sombras sin forma y espectros de datos corrompidos, danzan unos y ceros, serpenteando como entidades hambrientas, intentando desgarrar las defensas del código sagrado.**
#
# Entonces, un estruendo. No un simple sonido, sino una detonación primigenia que atraviesa el éter, reverberando a través del entramado mismo del universo. La realidad tiembla. El tejido del ciberespacio se retuerce. Y de la grieta en la red surge una voz, cavernosa y ancestral, un eco de desesperación y condena.
#
# **"¿Creyeron que podían derrotarme? ¡Yo, el poderoso Null Byte, he regresado! He venido a devorar sus códigos, a corromper sus sistemas, a imponer el vacío sobre su débil orden. Tiemblen, pues la entropía es inevitable."**
#
# #**Explicación sobre Pruebas de Escritorio en Programación**
#
# **¿Qué es una prueba de escritorio?**
#
# Una prueba de escritorio es una técnica utilizada en programación para simular la ejecución de un algoritmo o código sin necesidad de una computadora. Consiste en analizar línea por línea cómo se comporta el programa utilizando lápiz y papel, con el objetivo de detectar errores lógicos antes de ejecutarlo en un entorno real.
#
# **¿Cómo realizar una prueba de escritorio?**
#
# Para hacer una prueba de escritorio correctamente, se sigue el siguiente procedimiento:
#
# 1.	Escribir el código o algoritmo que se quiere probar.
# 2.	Identificar las variables y sus valores iniciales.
# 3.	Dibujar una tabla con las variables que se van a modificar durante la ejecución.
# 4.	Ejecutar el código línea por línea, registrando los cambios en la tabla.
# 5.	Observar si el resultado obtenido es el esperado o si hay errores.
#
# **Ejemplo de Prueba de Escritorio**
#
# Supongamos que tenemos el siguiente fragmento de código en Python:
#
# ![Imagen 14.png](data:image/png;base64,...)

# %% [markdown]
# **Ejercicio para los estudiantes**
#
#
# Ahora, intenta hacer una prueba de escritorio para el siguiente código y llena la tabla de variables:
# ![Imagen 15.png](data:image/png;base64,...)
